# %% [markdown]
# # Import Pandas

# %%
import pandas as pd

# %%
dadosImoveis = pd.read_csv('dados_imoveis.csv', sep = ',')

# %% [markdown]
# # Info about dataBase

# %%
dadosImoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# # DataFrame

# %%
dadosImoveis.head(15)
# Out:
#                                 Rua              Bairro     Cidade  Metragem  \
# 0             Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1    Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                   Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                               NaN      Jardim Morumbi  São Paulo       310
# 4          Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                   Rua Graham Bell         Santo Amaro  São Paulo       440
# 6          Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7       Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8           Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                        Rua Tapaji         Vila Alpina  São Paulo       114
# 10    Rua Vigário João Álvares, 66       Vila Monumento  São Paulo       261
# ...

# %% [markdown]
# # Calculando metragem média por bairro

# %%
dados_imoveis_bairro = dadosImoveis['Bairro']
dados_imoveis_metragem = dadosImoveis['Metragem']

# %% [markdown]
# # Gerando dataFrame bairro Jardim Morumbi

# %%
jardim_morumbi = dadosImoveis['Bairro'] == 'Jardim Morumbi'*1
jardim_morumbi_sum=sum(dadosImoveis['Bairro'] == 'Jardim Morumbi')

# %%
jardim_morumbi
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
jardins = dadosImoveis[jardim_morumbi]

# %% [markdown]
# # Metragem media Jardim Morumbi

# %%
dadosImoveis['Metragem'].mean()
# Out:
# 442.30065947242207

# %%
dadosImoveis[jardim_morumbi]['Metragem'].mean()
# Out:
# 624.457627118644

# %%
jardins['Metragem'].mean()
# Out:
# 624.457627118644

# %%
dadosImoveis[jardim_morumbi]
# Out:
#                                                     Rua          Bairro  \
# 3                                                   NaN  Jardim Morumbi
# 361                                                 NaN  Jardim Morumbi
# 408                                                 NaN  Jardim Morumbi
# 415                                                 NaN  Jardim Morumbi
# 618                         Rua Doutor Jesuíno de Abreu  Jardim Morumbi
# 634                         Rua Doutor Jesuíno de Abreu  Jardim Morumbi
# 694                       Rua Senador Otávio Mangabeira  Jardim Morumbi
# 720       Rua Doutor Manuel Carlos de Figueiredo Ferraz  Jardim Morumbi
# 762                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 785                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 818                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 841                     Rua Professor Luciano Gualberto  Jardim Morumbi
# ...

# %% [markdown]
# # Verificação jardim_morumbi.mean() para 'Metragem'

# %%
soma_metragem=sum(dadosImoveis[jardim_morumbi]["Metragem"])

# %%
soma_metragem
# Out:
# 36843

# %%
sum(jardim_morumbi.iloc())
# Out:
# 59

# %%
36843 / 59
# Out:
# 624.457627118644

# %% [markdown]
# # Verificação metragem acima de 1000m2

# %%
jardins.head()
# Out:
#                              Rua          Bairro     Cidade  Metragem  \
# 3                            NaN  Jardim Morumbi  São Paulo       310
# 361                          NaN  Jardim Morumbi  São Paulo       244
# 408                          NaN  Jardim Morumbi  São Paulo       445
# 415                          NaN  Jardim Morumbi  São Paulo       450
# 618  Rua Doutor Jesuíno de Abreu  Jardim Morumbi  São Paulo       285
#
#      Quartos  Banheiros  Vagas         Valor
# 3          3          2      4    R$ 685.000
# 361        3          5      2    R$ 890.000
# 408        2          3      4  R$ 1.900.000
# 415        2          3      4  R$ 1.900.000
# 618        3          5      3  R$ 1.250.000
